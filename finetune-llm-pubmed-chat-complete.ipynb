# %% [markdown]
# # Fine Tune LLM (On Text Classification Data)
#
# We'll walk through prepping data and fine-tuning a model in this notebook. Databricks makes it easy to fine tune a model with a few lines of code. We will be working with a text classification dataset: the [ml4pubmed dataset from hugging face](https://huggingface.co/datasets/ml4pubmed/pubmed-text-classification-cased) which contains text from different sections of scientific research articles.
#
# This notebook is the first in a series to showcase the performance gains provided by combining fine-tuning and prompt optimization. See this article for more [detail](https://www.databricks.com/blog/building-state-art-enterprise-agents-90x-cheaper-automated-prompt-optimization).

# %%
# %pip install databricks_genai
# %pip install databricks-sdk
dbutils.library.restartPython()
# Out:
# Collecting databricks_genai
#   Downloading databricks_genai-1.1.8-py3-none-any.whl.metadata (2.1 kB)
# Collecting backoff>=2.2.1 (from databricks_genai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting databricks-sdk<0.43,>=0.29.0 (from databricks_genai)
#   Downloading databricks_sdk-0.42.0-py3-none-any.whl.metadata (38 kB)
# Collecting datasets<=3.2,>=2.16.1 (from databricks_genai)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Collecting gql>=3.4.0 (from gql[websockets]>=3.4.0->databricks_genai)
#   Downloading gql-4.0.0-py3-none-any.whl.metadata (10 kB)
# Collecting mlflow<=2.20.2,>=2.14.2 (from databricks_genai)
#   Downloading mlflow-2.20.2-py3-none-any.whl.metadata (30 kB)
# Collecting mosaicml-cli<1,>=0.7.2 (from databricks_genai)
#   Downloading mosaicml_cli-0.8.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: requests<3,>=2.26.0 in /databricks/python3/lib/python3.12/site-packages (from databricks_genai) (2.32.2)
# Requirement already satisfied: typing_extensions>=4.7.1 in /databricks/python3/lib/python3.12/site-packages (from databricks_genai) (4.12.1)
# Requirement already satisfied: IPython<9,>=8 in /databricks/python3/lib/python3.12/site-packages (from databricks_genai) (8.32.0)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<0.43,>=0.29.0->databricks_genai) (2.38.0)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from datasets<=3.2,>=2.16.1->databricks_genai) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /databricks/python3/lib/python3.12/site-packages (from datasets<=3.2,>=2.16.1->databricks_genai) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /databricks/python3/lib/python3.12/site-packages (from datasets<=3.2,>=2.16.1->databricks_genai) (15.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /databricks/python3/lib/python3.12/site-packages (from datasets<=3.2,>=2.16.1->databricks_genai) (0.3.8)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (from datasets<=3.2,>=2.16.1->databricks_genai) (1.5.3)
# Collecting tqdm>=4.66.3 (from datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /databricks/python3/lib/python3.12/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets<=3.2,>=2.16.1->databricks_genai) (2024.3.1)
# Collecting aiohttp (from datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting huggingface-hub>=0.23.0 (from datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading huggingface_hub-1.3.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from datasets<=3.2,>=2.16.1->databricks_genai) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /databricks/python3/lib/python3.12/site-packages (from datasets<=3.2,>=2.16.1->databricks_genai) (6.0.1)
# Collecting graphql-core<3.3,>=3.2 (from gql>=3.4.0->gql[websockets]>=3.4.0->databricks_genai)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.6 (from gql>=3.4.0->gql[websockets]>=3.4.0->databricks_genai)
#   Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: anyio<5,>=3.0 in /databricks/python3/lib/python3.12/site-packages (from gql>=3.4.0->gql[websockets]>=3.4.0->databricks_genai) (4.2.0)
# Collecting websockets<16,>=14.2 (from gql[websockets]>=3.4.0->databricks_genai)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: decorator in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (4.8.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (2.15.1)
# Requirement already satisfied: stack_data in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /databricks/python3/lib/python3.12/site-packages (from IPython<9,>=8->databricks_genai) (5.14.3)
# Collecting mlflow-skinny==2.20.2 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading mlflow_skinny-2.20.2-py3-none-any.whl.metadata (31 kB)
# Collecting Flask<4 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /databricks/python3/lib/python3.12/site-packages (from mlflow<=2.20.2,>=2.14.2->databricks_genai) (3.1.4)
# Collecting alembic!=1.10.0,<2 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading alembic-1.18.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting docker<8,>=4.0.0 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting markdown<4,>=3.3 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow<=2.20.2,>=2.14.2->databricks_genai) (3.8.4)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.12/site-packages (from mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.4.2)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.12/site-packages (from mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.13.1)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading sqlalchemy-2.0.45-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (3.0.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (3.1.37)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (7.0.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.31.1)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (2.8.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (0.5.3)
# Collecting argcomplete>=2.0.0 (from mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading argcomplete-3.6.3-py3-none-any.whl.metadata (16 kB)
# Collecting arrow>=1.2.2 (from mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting questionary<2.2.0,>=2.0.0 (from mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading questionary-2.1.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting rich<14.0.0,>=12.6.0 (from mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting ruamel.yaml>=0.17.21 (from mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Collecting validators>=0.20.0 (from mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: urllib3>=1.23 in /databricks/python3/lib/python3.12/site-packages (from mosaicml-cli<1,>=0.7.2->databricks_genai) (2.2.2)
# Collecting termcolor>=1.1.0 (from mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.26.0->databricks_genai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.26.0->databricks_genai) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.26.0->databricks_genai) (2024.6.2)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.12/site-packages (from anyio<5,>=3.0->gql>=3.4.0->gql[websockets]>=3.4.0->databricks_genai) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /databricks/python3/lib/python3.12/site-packages (from arrow>=1.2.2->mosaicml-cli<1,>=0.7.2->databricks_genai) (2.9.0.post0)
# Requirement already satisfied: tzdata in /databricks/python3/lib/python3.12/site-packages (from arrow>=1.2.2->mosaicml-cli<1,>=0.7.2->databricks_genai) (2024.1)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /databricks/python3/lib/python3.12/site-packages (from Flask<4->mlflow<=2.20.2,>=2.14.2->databricks_genai) (2.1.3)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading werkzeug-3.1.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<0.43,>=0.29.0->databricks_genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<0.43,>=0.29.0->databricks_genai) (4.9)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub>=0.23.0->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub>=0.23.0->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting shellingham (from huggingface-hub>=0.23.0->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface-hub>=0.23.0->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /databricks/python3/lib/python3.12/site-packages (from jedi>=0.16->IPython<9,>=8->databricks_genai) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow<=2.20.2,>=2.14.2->databricks_genai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow<=2.20.2,>=2.14.2->databricks_genai) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.4.4)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow<=2.20.2,>=2.14.2->databricks_genai) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow<=2.20.2,>=2.14.2->databricks_genai) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->datasets<=3.2,>=2.16.1->databricks_genai) (2024.1)
# Requirement already satisfied: ptyprocess>=0.5 in /databricks/python3/lib/python3.12/site-packages (from pexpect>4.3->IPython<9,>=8->databricks_genai) (0.7.0)
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython<9,>=8->databricks_genai) (0.2.5)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=12.6.0->mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: joblib>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn<2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn<2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (2.2.0)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow<=2.20.2,>=2.14.2->databricks_genai)
#   Downloading greenlet-3.3.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: executing in /databricks/python3/lib/python3.12/site-packages (from stack_data->IPython<9,>=8->databricks_genai) (0.8.3)
# Requirement already satisfied: asttokens in /databricks/python3/lib/python3.12/site-packages (from stack_data->IPython<9,>=8->databricks_genai) (2.0.5)
# Requirement already satisfied: pure-eval in /databricks/python3/lib/python3.12/site-packages (from stack_data->IPython<9,>=8->databricks_genai) (0.2.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (4.0.11)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets<=3.2,>=2.16.1->databricks_genai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (3.17.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=12.6.0->mosaicml-cli<1,>=0.7.2->databricks_genai)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: deprecated>=1.2.6 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (0.52b1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<0.43,>=0.29.0->databricks_genai) (0.4.8)
# Requirement already satisfied: annotated-types>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (2.20.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.0->arrow>=1.2.2->mosaicml-cli<1,>=0.7.2->databricks_genai) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /databricks/python3/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.2->mlflow<=2.20.2,>=2.14.2->databricks_genai) (5.0.0)
# Downloading databricks_genai-1.1.8-py3-none-any.whl (44 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading databricks_sdk-0.42.0-py3-none-any.whl (643 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 643.8/643.8 kB 33.1 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
# Downloading gql-4.0.0-py3-none-any.whl (89 kB)
# Downloading mlflow-2.20.2-py3-none-any.whl (28.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 99.4 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.20.2-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 148.8 MB/s eta 0:00:00
# Downloading mosaicml_cli-0.8.3-py3-none-any.whl (238 kB)
# Downloading alembic-1.18.0-py3-none-any.whl (260 kB)
# Downloading argcomplete-3.6.3-py3-none-any.whl (43 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading aiohttp-3.13.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 116.5 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading huggingface_hub-1.3.1-py3-none-any.whl (533 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.4/533.4 kB 53.2 MB/s eta 0:00:00
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading questionary-2.1.1-py3-none-any.whl (36 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
# Downloading sqlalchemy-2.0.45-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 145.0 MB/s eta 0:00:00
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
# Downloading xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading greenlet-3.3.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (609 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.9/609.9 kB 71.8 MB/s eta 0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 145.1 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
# Downloading werkzeug-3.1.5-py3-none-any.whl (225 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: xxhash, werkzeug, websockets, validators, typer-slim, tqdm, termcolor, shellingham, ruamel.yaml, propcache, multiprocess, multidict, mdurl, markdown, Mako, itsdangerous, hf-xet, h11, gunicorn, greenlet, graphql-core, frozenlist, blinker, backoff, attrs, argcomplete, aiohappyeyeballs, yarl, sqlalchemy, questionary, markdown-it-py, httpcore, graphql-relay, Flask, docker, arrow, aiosignal, rich, httpx, graphene, gql, databricks-sdk, alembic, aiohttp, huggingface-hub, mosaicml-cli, mlflow-skinny, datasets, mlflow, databricks_genai
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Not uninstalling h11 at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-268010a8-bedc-4280-970e-c99e4e6ec5c5
#     Can't uninstall 'h11'. No files were found to uninstall.
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.7.0
#     Not uninstalling blinker at /usr/lib/python3/dist-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-268010a8-bedc-4280-970e-c99e4e6ec5c5
#     Can't uninstall 'blinker'. No files were found to uninstall.
#   Attempting uninstall: databricks-sdk
#     Found existing installation: databricks-sdk 0.49.0
#     Not uninstalling databricks-sdk at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-268010a8-bedc-4280-970e-c99e4e6ec5c5
#     Can't uninstall 'databricks-sdk'. No files were found to uninstall.
#   Attempting uninstall: mlflow-skinny
#     Found existing installation: mlflow-skinny 2.21.3
#     Not uninstalling mlflow-skinny at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-268010a8-bedc-4280-970e-c99e4e6ec5c5
#     Can't uninstall 'mlflow-skinny'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-connect 16.4.2 requires databricks-sdk>=0.46.0, but you have databricks-sdk 0.42.0 which is incompatible.
# serverless-gpu 0.5.2 requires databricks-connect<16,>=15.4.2, but you have databricks-connect 16.4.2 which is incompatible.
# serverless-gpu 0.5.2 requires databricks-sdk<1,>=0.49, but you have databricks-sdk 0.42.0 which is incompatible.
# Successfully installed Flask-3.1.2 Mako-1.3.10 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 alembic-1.18.0 argcomplete-3.6.3 arrow-1.4.0 attrs-25.4.0 backoff-2.2.1 blinker-1.9.0 databricks-sdk-0.42.0 databricks_genai-1.1.8 datasets-3.2.0 docker-7.1.0 frozenlist-1.8.0 gql-4.0.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 greenlet-3.3.0 gunicorn-23.0.0 h11-0.16.0 hf-xet-1.2.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.3.1 itsdangerous-2.2.0 markdown-3.10 markdown-it-py-4.0.0 mdurl-0.1.2 mlflow-2.20.2 mlflow-skinny-2.20.2 mosaicml-cli-0.8.3 multidict-6.7.0 multiprocess-0.70.16 propcache-0.4.1 questionary-2.1.1 rich-13.9.4 ruamel.yaml-0.19.1 shellingham-1.5.4 sqlalchemy-2.0.45 termcolor-3.3.0 tqdm-4.67.1 typer-slim-0.21.1 validators-0.35.0 websockets-15.0.1 werkzeug-3.1.5 xxhash-3.6.0 yarl-1.22.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: databricks-sdk in /local_disk0/.ephemeral_nfs/envs/pythonEnv-268010a8-bedc-4280-970e-c99e4e6ec5c5/lib/python3.12/site-packages (0.42.0)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk) (2.38.0)
# Requirement already satisfied: requests<3,>=2.28.1 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk) (2.32.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk) (4.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk) (2024.6.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk) (0.4.8)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from databricks.model_training import foundation_model as fm
from datasets import load_dataset
import os
import mlflow
from typing import Dict
from pyspark.sql.functions import col
from pyspark.sql import DataFrame

# %% [markdown]
# ## Set Variables & Prompt
#
# Let's set the Unity Catalog location we'd like to register our finetuned model to.

# %%
catalog = "megan_fang_demos"
schema = "llm_opt"
model_name = "cc-meta-llama-3-1-8b-instruct"
registered_model_name = f"{catalog}.{schema}.{model_name}"
dataset = "ml4pubmed/pubmed-text-classification-cased"

spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema}")

os.environ["HF_DATASETS_CACHE"] = "/Volumes/megan_fang_demos/llm_opt/datasets"

# %% [markdown]
# Let's include a helpful system prompt for our LLM. Without this system prompt, the LLM is too verbose and doesn't perform well on our simple text classification task. When I did inference without the system prompt, the LLM had 0% accuracy.

# %%
system_prompt = """Given a text field containing a sentence from a research paper abstract, classify it into one of the following categories and output only the category label:

**Categories:**
- BACKGROUND: Contextual information, established knowledge, problem statements, or general facts that set up the research context (e.g., "Although opioids are effective treatments for postoperative pain, they contribute to the delayed recovery of gastrointestinal function.")
- OBJECTIVE: Research aims, goals, purposes, hypotheses, or what the study was designed to investigate (e.g., "This study was designed to assess...", "The aim was to investigate...", "To determine whether...")
- METHODS: Descriptions of experimental procedures, data collection methods, study protocols, analytical approaches, statistical methods, or control group descriptions (e.g., "Blood samples were collected...", "This fifth group served as a control...", "mean (+/- SD) was used")
- RESULTS: Findings, outcomes, statistical data, success rates, observed effects, or factual outcomes from the study (e.g., "The success rate was 70.4%...", "Follow-up coronary angiography was performed in 108 patients...", "a significant improvement in terms of OS (p = 0.02)")
- CONCLUSIONS: Final interpretations, implications, recommendations, suggestions, or what the authors conclude from their findings. These often contain interpretive language and speculation (e.g., "From this finding, we conclude that...", "may be associated with...")

**Critical Classification Guidelines:**

1. **OBJECTIVE vs BACKGROUND**: 
    - Sentences describing what a study "was designed to," "aimed to," "evaluated whether," or starting with "To determine/investigate" are OBJECTIVE, not BACKGROUND
    - "There is a need to..." statements are OBJECTIVE (expressing research purpose), not BACKGROUND
    - Study purpose statements are always OBJECTIVE regardless of their position in the abstract

2. **RESULTS vs CONCLUSIONS**: 
    - RESULTS report factual findings, statistical outcomes, and observed data without interpretation
    - CONCLUSIONS contain interpretive statements with words like "may be," "suggest," "conclude," "might," or implications drawn from results
    - Statements with "evidence suggesting" are CONCLUSIONS, not BACKGROUND

3. **Key Phrases for OBJECTIVE**: 
    - "There is a need to..."
    - "This study evaluated whether..."
    - "was designed to assess..."
    - "The aim was to..."
    - "To determine..."
    - "This clinical study was designed to assess whether..."

4. **Key Phrases for CONCLUSIONS**: 
    - "we conclude that..."
    - "may be associated with..."
    - "might benefit from..."
    - "suggest that..."
    - "evidence suggesting..."
    - Any speculative or interpretive language

5. **METHODS indicators**: 
    - Descriptions of procedures, controls, statistical approaches
    - Data collection timing and methods
    - Analytical methods and statistical significance thresholds
    - Control group descriptions

6. **Focus on primary purpose**: Classify based on the main function of the sentence in the research narrative, not just its position in the abstract.

**Common Misclassification Patterns to Avoid:**
- Study objectives stated as "This study was designed to..." should be OBJECTIVE, not BACKGROUND
- "There is a need to identify..." statements are OBJECTIVE, not BACKGROUND
- Statements with "may be associated with" or similar speculative language are CONCLUSIONS, not RESULTS
- "Evidence suggesting" statements are CONCLUSIONS, not BACKGROUND
- Research aims are always OBJECTIVE regardless of how they are phrased

**Classification Strategy:**
1. Look for explicit objective markers first (study aims, purposes, "to determine")
2. Check for speculative/interpretive language indicating CONCLUSIONS
3. Identify factual data reporting for RESULTS
4. Look for procedural descriptions for METHODS
5. Default to BACKGROUND only for established knowledge or context-setting information

Based on the above, categorize the following sentence and output only the category label (BACKGROUND, OBJECTIVE, METHODS, RESULTS, or CONCLUSIONS) without any additional text or explanation : \n\n"""

# %% [markdown]
# ## Test Base Model
#
# Let's test the performance of our LLM before fine-tuning to get a baseline performance.

# %%
test_table_name = "hf_pubmed_test"
pred = spark.sql(f"""
        SELECT
            ai_query('databricks-meta-llama-3-1-8b-instruct', concat('{system_prompt}', prompt)) AS prediction,
            response,
            prompt
        FROM {catalog}.{schema}.{test_table_name}
        """)
display(pred.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prediction</th><th>response</th><th>prompt</th></tr></thead><tbody><tr><td>OBJECTIVE</td><td>BACKGROUND</td><td>Many pathogenic processes and diseases are the result of an erroneous activation of the complement cascade and a number of inhibitors of complement have thus been examined for anti-inflammatory actions .</td></tr><tr><td>OBJECTIVE</td><td>BACKGROUND</td><td>It was recently demonstrated that supraphysiological concentrations of the endogenous complement inhibitor MAp44 ( also denoted MAP1 ) protect against myocardial reperfusion injury .</td></tr><tr><td>OBJECTIVE</td><td>BACKGROUND</td><td>In the present study , we examined the association between outcome after acute myocardial infarction ( MI ) and the plasma levels of MAp44 and its related proteins MASP-1 and MASP-3 in patients with first-time MI .</td></tr><tr><td>METHODS</td><td>BACKGROUND</td><td>In addition , we compared plasma levels of MAp44 , MASP-1 , and MASP-3 in MI patients to levels in a healthy control group .</td></tr><tr><td>RESULTS</td><td>METHODS</td><td>A total of 192 MI patients and 140 control persons were included .</td></tr></tbody></table></div>

# %%
total_count = pred.count()
correct_predictions = pred.filter(col("prediction") == col("response")).count()
overall_accuracy = correct_predictions / total_count

print(f"Total samples: {total_count}")
print(f"Baseline Accuracy: {overall_accuracy:.4f}")
# Out:
# Total samples: 29493
# Baseline Accuracy: 0.6291

# %% [markdown]
# We have a baseline accuracy of 62.91%. Let's load our data to finetune our model and see how much the performance improves.

# %% [markdown]
# ## Load Data

# %%
def load_hf_dataset(dataset: str, split: str="train", include_cols: list[str]=['prompt', 'response'], rename_cols: Dict | None = None, register_to_uc: bool=False, catalog: str=catalog, schema: str=schema, table_name: str="hf_pubmed_train") -> DataFrame:
  """
  Load dataset from hugging face and converts to spark dataframe. Optionally register to Unity Catalog.

  Args:
    dataset (str): Hugging Face dataset name
    split (str): Dataset split to load. Defaults to "train"
    include_cols (list): Columns to include in the final dataframe. Defaults to ['prompt', 'response']
    rename_cols (dict | None): Dictionary of column names to rename. Defaults to None
    register_to_uc (bool): Whether to register the dataframe to Unity Catalog. Defaults to False
    catalog (str): Unity Catalog catalog name. Defaults to catalog
    schema (str): Unity Catalog schema name. Defaults to schema
    table_name (str): Unity Catalog table name
  Returns:
    Spark Dataframe: Converted dataframe
  """
  # Load hugging face dataset
  hf_df = load_dataset(
      path=dataset,
      split=split
  )

  # Convert to pandas then spark dataframe
  pd_df = hf_df.to_pandas()[include_cols].dropna()
  hf_spark = spark.createDataFrame(pd_df)

  if rename_cols is not None:
    hf_spark = hf_spark.withColumnRenamed(rename_cols["prompt"], "prompt").withColumnRenamed(rename_cols["response"], "response")

  # Optionally register to unity catalog
  if register_to_uc:
    hf_spark.write.format("delta").mode("overwrite").saveAsTable(f"{catalog}.{schema}.{table_name}")

  return hf_spark

# %%
train_table_name = "hf_pubmed_train"
rename_cols = {"prompt": "description", "response": "target"}

hf_train = load_hf_dataset(dataset=dataset, include_cols=['target', 'description'], rename_cols=rename_cols, register_to_uc=True, table_name=train_table_name)
# Out:
# /databricks/python_shell/lib/dbruntime/huggingface_patches/datasets.py:24: UserWarning: During large dataset downloads, there could be multiple progress bar widgets that can cause performance issues for your notebook or browser. To avoid these issues, use `datasets.utils.logging.disable_progress_bar()` to turn off the progress bars.
#   warnings.warn(
# README.md:   0%|          | 0.00/255 [00:00<?, ?B/s]
# train.csv:   0%|          | 0.00/690M [00:00<?, ?B/s]
# dev.csv:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# test.csv:   0%|          | 0.00/9.14M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2211861 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/28932 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/29493 [00:00<?, ? examples/s]

# %%
eval_table_name = "hf_pubmed_eval"
hf_eval = load_hf_dataset(dataset=dataset, split="validation", include_cols=['target', 'description'], rename_cols=rename_cols, register_to_uc=True, table_name=eval_table_name)
# Out:
# /databricks/python_shell/lib/dbruntime/huggingface_patches/datasets.py:24: UserWarning: During large dataset downloads, there could be multiple progress bar widgets that can cause performance issues for your notebook or browser. To avoid these issues, use `datasets.utils.logging.disable_progress_bar()` to turn off the progress bars.
#   warnings.warn(

# %% [markdown]
# ## Transform Data For Chat Completion
#
# Databricks fine-tuning supports a few different task types:
#
# - **Chat completion**: Train your model on chat logs between a user and an AI assistant. The text is automatically formatted into the appropriate format for the specific model.
# - **Instruction fine-tuning**: Train your model on structured prompt-response data. Use this to adapt your model to a new task, change its response style, or add instruction-following capabilities. This task does not automatically apply any formatting to your data and is only recommended when custom data formatting is required.
#
# I found chat completion to perform better than instruction fine-tuning for this task, so let's format our data for chat completion.
#
# Chat completion requires a list of role and prompt, following the OpenAI standard:

# %%
[
  {"role": "system", "content": "[system prompt]"},
  {"role": "user", "content": "Here is a documentation page:[RAG context]. Based on this, answer the following question: [user question]"},
  {"role": "assistant", "content": "[answer]"}
]
# Out:
# [{'role': 'system', 'content': '[system prompt]'},
#  {'role': 'user',
#   'content': 'Here is a documentation page:[RAG context]. Based on this, answer the following question: [user question]'},
#  {'role': 'assistant', 'content': '[answer]'}]

# %%
spark.sql(f"""
CREATE OR REPLACE TABLE hf_pubmed_train_chat_complete AS
SELECT 
    ARRAY(
        STRUCT('user' AS role, CONCAT('{system_prompt}', '\n', prompt) AS content),
        STRUCT('assistant' AS role, response AS content)
    ) AS messages
FROM hf_pubmed_train;
""")

spark.table('hf_pubmed_train_chat_complete').limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>messages</th></tr></thead><tbody><tr><td>List(List(user, Given a text field containing a sentence from a research paper abstract, classify it into one of the following categories and output only the category label:
#
# **Categories:**
# - BACKGROUND: Contextual information, established knowledge, problem statements, or general facts that set up the research context (e.g., "Although opioids are effective treatments for postoperative pain, they contribute to the delayed recovery of gastrointestinal function.")
# - OBJECTIVE: Research aims, goals, purposes, hypotheses, or what the study was designed to investigate (e.g., "This study was designed to assess...", "The aim was to investigate...", "To determine whether...")
# - METHODS: Descriptions of experimental procedures, data collection methods, study protocols, analytical approaches, statistical methods, or control group descriptions (e.g., "Blood samples were collected...", "This fifth group served as a control...", "mean (+/- SD) was used")
# - RESULTS: Findings, outcomes, statistical data, success rates, observed effects, or factual outcomes from the study (e.g., "The success rate was 70.4%...", "Follow-up coronary angiography was performed in 108 patients...", "a significant improvement in terms of OS (p = 0.02)")
# - CONCLUSIONS: Final interpretations, implications, recommendations, suggestions, or what the authors conclude from their findings. These often contain interpretive language and speculation (e.g., "From this finding, we conclude that...", "may be associated with...")
#
# **Critical Classification Guidelines:**
#
# 1. **OBJECTIVE vs BACKGROUND**:
#     - Sentences describing what a study "was designed to," "aimed to," "evaluated whether," or starting with "To determine/investigate" are OBJECTIVE, not BACKGROUND
#     - "There is a need to..." statements are OBJECTIVE (expressing research purpose), not BACKGROUND
#     - Study purpose statements are always OBJECTIVE regardless of their position in the abstract
#
# 2. **RESULTS vs CONCLUSIONS**:
#     - RESULTS report factual findings, statistical outcomes, and observed data without interpretation
#     - CONCLUSIONS contain interpretive statements with words like "may be," "suggest," "conclude," "might," or implications drawn from results
#     - Statements with "evidence suggesting" are CONCLUSIONS, not BACKGROUND
#
# 3. **Key Phrases for OBJECTIVE**:
#     - "There is a need to..."
#     - "This study evaluated whether..."
#     - "was designed to assess..."
#     - "The aim was to..."
#     - "To determine..."
#     - "This clinical study was designed to assess whether..."
#
# 4. **Key Phrases for CONCLUSIONS**:
#     - "we conclude that..."
#     - "may be associated with..."
#     - "might benefit from..."
#     - "suggest that..."
#     - "evidence suggesting..."
#     - Any speculative or interpretive language
#
# 5. **METHODS indicators**:
#     - Descriptions of procedures, controls, statistical approaches
#     - Data collection timing and methods
#     - Analytical methods and statistical significance thresholds
#     - Control group descriptions
#
# 6. **Focus on primary purpose**: Classify based on the main function of the sentence in the research narrative, not just its position in the abstract.
#
# **Common Misclassification Patterns to Avoid:**
# - Study objectives stated as "This study was designed to..." should be OBJECTIVE, not BACKGROUND
# - "There is a need to identify..." statements are OBJECTIVE, not BACKGROUND
# - Statements with "may be associated with" or similar speculative language are CONCLUSIONS, not RESULTS
# - "Evidence suggesting" statements are CONCLUSIONS, not BACKGROUND
# - Research aims are always OBJECTIVE regardless of how they are phrased
#
# **Classification Strategy:**
# 1. Look for explicit objective markers first (study aims, purposes, "to determine")
# 2. Check for speculative/interpretive language indicating CONCLUSIONS
# 3. Identify factual data reporting for RESULTS
# 4. Look for procedural descriptions for METHODS
# 5. Default to BACKGROUND only for established knowledge or context-setting information
#
# Based on the above, categorize the following sentence and output only the category label (BACKGROUND, OBJECTIVE, METHODS, RESULTS, or CONCLUSIONS) without any additional text or explanation :
#
#
# Individuals receiving therapeutic LPs had higher cerebrospinal fluid ( CSF ) opening pressures , higher CSF fungal burdens , and were more likely to have altered mental status at baseline than those with no therapeutic LPs .), List(assistant, RESULTS))</td></tr><tr><td>List(List(user, Given a text field containing a sentence from a research paper abstract, classify it into one of the following categories and output only the category label:
#
# **Categories:**
# - BACKGROUND: Contextual information, established knowledge, problem statements, or general facts that set up the research context (e.g., "Although opioids are effective treatments for postoperative pain, they contribute to the delayed recovery of gastrointestinal function.")
# - OBJECTIVE: Research aims, goals, purposes, hypotheses, or what the study was designed to investigate (e.g., "This study was designed to assess...", "The aim was to investigate...", "To determine whether...")
# - METHODS: Descriptions of experimental procedures, data collection methods, study protocols, analytical approaches, statistical methods, or control group descriptions (e.g., "Blood samples were collected...", "This fifth group served as a control...", "mean (+/- SD) was used")
# - RESULTS: Findings, outcomes, statistical data, success rates, observed effects, or factual outcomes from the study (e.g., "The success rate was 70.4%...", "Follow-up coronary angiography was performed in 108 patients...", "a significant improvement in terms of OS (p = 0.02)")
# - CONCLUSIONS: Final interpretations, implications, recommendations, suggestions, or what the authors conclude from their findings. These often contain interpretive language and speculation (e.g., "From this finding, we conclude that...", "may be associated with...")
#
# **Critical Classification Guidelines:**
#
# 1. **OBJECTIVE vs BACKGROUND**:
#     - Sentences describing what a study "was designed to," "aimed to," "evaluated whether," or starting with "To determine/investigate" are OBJECTIVE, not BACKGROUND
#     - "There is a need to..." statements are OBJECTIVE (expressing research purpose), not BACKGROUND
#     - Study purpose statements are always OBJECTIVE regardless of their position in the abstract
#
# 2. **RESULTS vs CONCLUSIONS**:
#     - RESULTS report factual findings, statistical outcomes, and observed data without interpretation
#     - CONCLUSIONS contain interpretive statements with words like "may be," "suggest," "conclude," "might," or implications drawn from results
#     - Statements with "evidence suggesting" are CONCLUSIONS, not BACKGROUND
#
# 3. **Key Phrases for OBJECTIVE**:
#     - "There is a need to..."
#     - "This study evaluated whether..."
#     - "was designed to assess..."
#     - "The aim was to..."
#     - "To determine..."
#     - "This clinical study was designed to assess whether..."
#
# 4. **Key Phrases for CONCLUSIONS**:
#     - "we conclude that..."
#     - "may be associated with..."
#     - "might benefit from..."
#     - "suggest that..."
#     - "evidence suggesting..."
#     - Any speculative or interpretive language
#
# 5. **METHODS indicators**:
#     - Descriptions of procedures, controls, statistical approaches
#     - Data collection timing and methods
#     - Analytical methods and statistical significance thresholds
#     - Control group descriptions
#
# 6. **Focus on primary purpose**: Classify based on the main function of the sentence in the research narrative, not just

# %%
spark.sql(f"""
CREATE OR REPLACE TABLE hf_pubmed_eval_chat_complete AS
SELECT 
    ARRAY(
        STRUCT('user' AS role, CONCAT('{system_prompt}', '\n', prompt) AS content),
        STRUCT('assistant' AS role, response AS content)
    ) AS messages
FROM hf_pubmed_eval;
""")

spark.table('hf_pubmed_eval_chat_complete').limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>messages</th></tr></thead><tbody><tr><td>List(List(user, Given a text field containing a sentence from a research paper abstract, classify it into one of the following categories and output only the category label:
#
# **Categories:**
# - BACKGROUND: Contextual information, established knowledge, problem statements, or general facts that set up the research context (e.g., "Although opioids are effective treatments for postoperative pain, they contribute to the delayed recovery of gastrointestinal function.")
# - OBJECTIVE: Research aims, goals, purposes, hypotheses, or what the study was designed to investigate (e.g., "This study was designed to assess...", "The aim was to investigate...", "To determine whether...")
# - METHODS: Descriptions of experimental procedures, data collection methods, study protocols, analytical approaches, statistical methods, or control group descriptions (e.g., "Blood samples were collected...", "This fifth group served as a control...", "mean (+/- SD) was used")
# - RESULTS: Findings, outcomes, statistical data, success rates, observed effects, or factual outcomes from the study (e.g., "The success rate was 70.4%...", "Follow-up coronary angiography was performed in 108 patients...", "a significant improvement in terms of OS (p = 0.02)")
# - CONCLUSIONS: Final interpretations, implications, recommendations, suggestions, or what the authors conclude from their findings. These often contain interpretive language and speculation (e.g., "From this finding, we conclude that...", "may be associated with...")
#
# **Critical Classification Guidelines:**
#
# 1. **OBJECTIVE vs BACKGROUND**:
#     - Sentences describing what a study "was designed to," "aimed to," "evaluated whether," or starting with "To determine/investigate" are OBJECTIVE, not BACKGROUND
#     - "There is a need to..." statements are OBJECTIVE (expressing research purpose), not BACKGROUND
#     - Study purpose statements are always OBJECTIVE regardless of their position in the abstract
#
# 2. **RESULTS vs CONCLUSIONS**:
#     - RESULTS report factual findings, statistical outcomes, and observed data without interpretation
#     - CONCLUSIONS contain interpretive statements with words like "may be," "suggest," "conclude," "might," or implications drawn from results
#     - Statements with "evidence suggesting" are CONCLUSIONS, not BACKGROUND
#
# 3. **Key Phrases for OBJECTIVE**:
#     - "There is a need to..."
#     - "This study evaluated whether..."
#     - "was designed to assess..."
#     - "The aim was to..."
#     - "To determine..."
#     - "This clinical study was designed to assess whether..."
#
# 4. **Key Phrases for CONCLUSIONS**:
#     - "we conclude that..."
#     - "may be associated with..."
#     - "might benefit from..."
#     - "suggest that..."
#     - "evidence suggesting..."
#     - Any speculative or interpretive language
#
# 5. **METHODS indicators**:
#     - Descriptions of procedures, controls, statistical approaches
#     - Data collection timing and methods
#     - Analytical methods and statistical significance thresholds
#     - Control group descriptions
#
# 6. **Focus on primary purpose**: Classify based on the main function of the sentence in the research narrative, not just its position in the abstract.
#
# **Common Misclassification Patterns to Avoid:**
# - Study objectives stated as "This study was designed to..." should be OBJECTIVE, not BACKGROUND
# - "There is a need to identify..." statements are OBJECTIVE, not BACKGROUND
# - Statements with "may be associated with" or similar speculative language are CONCLUSIONS, not RESULTS
# - "Evidence suggesting" statements are CONCLUSIONS, not BACKGROUND
# - Research aims are always OBJECTIVE regardless of how they are phrased
#
# **Classification Strategy:**
# 1. Look for explicit objective markers first (study aims, purposes, "to determine")
# 2. Check for speculative/interpretive language indicating CONCLUSIONS
# 3. Identify factual data reporting for RESULTS
# 4. Look for procedural descriptions for METHODS
# 5. Default to BACKGROUND only for established knowledge or context-setting information
#
# Based on the above, categorize the following sentence and output only the category label (BACKGROUND, OBJECTIVE, METHODS, RESULTS, or CONCLUSIONS) without any additional text or explanation :
#
#
# Adrenergic activation is thought to be an important determinant of outcome in subjects with chronic heart failure ( CHF ) , but baseline or serial changes in adrenergic activity have not been previously investigated in a large patient sample treated with a powerful antiadrenergic agent .), List(assistant, BACKGROUND))</td></tr><tr><td>List(List(user, Given a text field containing a sentence from a research paper abstract, classify it into one of the following categories and output only the category label:
#
# **Categories:**
# - BACKGROUND: Contextual information, established knowledge, problem statements, or general facts that set up the research context (e.g., "Although opioids are effective treatments for postoperative pain, they contribute to the delayed recovery of gastrointestinal function.")
# - OBJECTIVE: Research aims, goals, purposes, hypotheses, or what the study was designed to investigate (e.g., "This study was designed to assess...", "The aim was to investigate...", "To determine whether...")
# - METHODS: Descriptions of experimental procedures, data collection methods, study protocols, analytical approaches, statistical methods, or control group descriptions (e.g., "Blood samples were collected...", "This fifth group served as a control...", "mean (+/- SD) was used")
# - RESULTS: Findings, outcomes, statistical data, success rates, observed effects, or factual outcomes from the study (e.g., "The success rate was 70.4%...", "Follow-up coronary angiography was performed in 108 patients...", "a significant improvement in terms of OS (p = 0.02)")
# - CONCLUSIONS: Final interpretations, implications, recommendations, suggestions, or what the authors conclude from their findings. These often contain interpretive language and speculation (e.g., "From this finding, we conclude that...", "may be associated with...")
#
# **Critical Classification Guidelines:**
#
# 1. **OBJECTIVE vs BACKGROUND**:
#     - Sentences describing what a study "was designed to," "aimed to," "evaluated whether," or starting with "To determine/investigate" are OBJECTIVE, not BACKGROUND
#     - "There is a need to..." statements are OBJECTIVE (expressing research purpose), not BACKGROUND
#     - Study purpose statements are always OBJECTIVE regardless of their position in the abstract
#
# 2. **RESULTS vs CONCLUSIONS**:
#     - RESULTS report factual findings, statistical outcomes, and observed data without interpretation
#     - CONCLUSIONS contain interpretive statements with words like "may be," "suggest," "conclude," "might," or implications drawn from results
#     - Statements with "evidence suggesting" are CONCLUSIONS, not BACKGROUND
#
# 3. **Key Phrases for OBJECTIVE**:
#     - "There is a need to..."
#     - "This study evaluated whether..."
#     - "was designed to assess..."
#     - "The aim was to..."
#     - "To determine..."
#     - "This clinical study was designed to assess whether..."
#
# 4. **Key Phrases for CONCLUSIONS**:
#     - "we conclude that..."
#     - "may be associated with..."
#     - "might benefit from..."
#     - "suggest that..."
#     - "evidence suggesting..."
#     - Any speculative or interpretive language
#
# 5. **METHODS indicators**:
#     - Descriptions of procedures, controls, statistical approaches
#     - Data collection timing and methods
#     - Analytical methods and statistical significance thresholds
#     - Control group descriptions
#
# 6. **Focus on primary purpose**: Classify based on th

# %% [markdown]
# ## Start Fine Tuning Run
#
# See supported model types and more details on databricks' fine tuning module [here](https://docs.databricks.com/aws/en/large-language-models/foundation-model-training/).

# %%
def get_current_cluster_id():
  import json
  return json.loads(dbutils.notebook.entry_point.getDbutils().notebook().getContext().safeToJson())['attributes']['clusterId']

# %%
run = fm.create(model="meta-llama/Meta-Llama-3.1-8B-Instruct",
                data_prep_cluster_id=get_current_cluster_id(), # necessary when using a Unity Catalog dataset to train
                train_data_path=f"{catalog}.{schema}.{train_table_name}",
                eval_data_path=f"{catalog}.{schema}.{eval_table_name}",
                register_to=f"{catalog}.{schema}.{model_name}",
                task_type="CHAT_COMPLETION",
                learning_rate="5e-8",
                training_duration="10ep") #10 epochs for demo in interest of time
run
# Out:
# Logged a <a href=/ml/experiments/3873581080081785/runs/dc7ffd6f2da04b099dd5ca967f7a316e class target='_blank'>run</a> to an <a href=/ml/experiments/3873581080081785 class target='_blank'>experiment</a> in MLflow. Experiment ID: <input type="text" value="3873581080081785"readonly="readonly" style="border:none;background:none;cursor:pointer;" onclick="this.select();">
# TrainingRun(name='ift-meta-llama-3-1-8b-instruct-ugot7x', status=<RunStatus.PENDING: 'PENDING'>, created_by='megan.fang@databricks.com', model='meta-llama/Meta-Llama-3.1-8B-Instruct', save_folder='dbfs:/databricks/mlflow-tracking/{mlflow_experiment_id}/{mlflow_run_id}/artifacts', train_data_path='megan_fang_demos.llm_opt.hf_pubmed_train', register_to='megan_fang_demos.llm_opt.cc-meta-llama-3-1-8b-instruct', submitted_experiment_path='/Users/megan.fang@databricks.com/ift-meta-llama-3-1-8b-instruct-ugot7x', task_type='CHAT_COMPLETION', eval_data_path='megan_fang_demos.llm_opt.hf_pubmed_eval', eval_prompts=[], custom_weights_path=None, training_duration='15ep', learning_rate=5e-08, context_length=8192, data_prep_cluster_id='1008-013510-bk8gpb9j', details='The service is currently experiencing high demand. Your run will start as soon as compute becomes available.', created_at=datetime.datetime(2025, 10, 16, 12, 34, 44, 170000, tzinfo=datetime.timezone.utc), started_at=None, estimated_end_time=None, formatted_eta=None, completed_at=None, submitted_config=TrainConfig(model='meta-llama/Meta-Llama-3.1-8B-Instruct', train_data_path='megan_fang_demos.llm_opt.hf_pubmed_train', save_folder='dbfs:/databricks/mlflow-tracking/{mlflow_experiment_id}/{mlflow_run_id}/artifacts', task_type='CHAT_COMPLETION', eval_data_path='megan_fang_demos.llm_opt.hf_pubmed_eval', eval_prompts=[], custom_weights_path=None, training_duration='15ep', training_durations=None, experiment_tracker={'mlflow': {'experiment_path': '/Users/megan.fang@databricks.com/ift-meta-llama-3-1-8b-instruct-ugot7x', 'tracking_uri': 'databricks', 'model_registry_path': 'megan_fang_demos.llm_opt.cc-meta-llama-3-1-8b-instruct', 'mlflowExperimentId': '3873581080081785', 'mlflowRunId': 'dc7ffd6f2da04b099dd5ca967f7a316e'}}, learning_rate=5e-08, learning_rates=None, context_length=8192, data_prep_config=None, disable_credentials_check=None), events=List[], experiment_id='3873581080081785', run_id='dc7ffd6f2da04b099dd5ca967f7a316e', _required_properties=('id', 'name', 'status', 'createdByEmail', 'createdAt', 'updatedAt'))

# %% [markdown]
# Here are the metrics from the MLFlow experiment associated with my fine tuning run. As you can see, the eval metrics are improving. If your metrics are not improving, here are some tips:
#
# - Increase learning rate if loss is decreasing but very slowly
# - Decrease learning rate if loss is varying a lot
# - Add more epochs if your model still improving at the end of your run
#
#
# <img src="https://github.com/mfang73/llm-finetuning-guide/blob/main/finetune-mlflow.png?raw=true" width="1200px">

# %%
from mlflow import MlflowClient
mlflow.set_registry_uri("databricks-uc")
client = MlflowClient()

# Get latest version
versions = client.search_model_versions(f"name='{catalog}.{schema}.{model_name}'")
latest_version = max(versions, key=lambda mv: int(mv.version)).version

# Create or update the alias to point at the specified version
alias = "champion"
client.set_registered_model_alias(name=f"{catalog}.{schema}.{model_name}", alias=alias, version=latest_version)

# %% [markdown]
# ## Create Serving Endpoint

# %%
from databricks.sdk import WorkspaceClient
from databricks.sdk.service.serving import (
    ServedEntityInput,
    EndpointCoreConfigInput,
    AiGatewayConfig,
    AiGatewayInferenceTableConfig
)

serving_endpoint_name = "cc-meta-llama-3-1-8b-instruct"
w = WorkspaceClient()

# Create the AI Gateway configuration
ai_gateway_config = AiGatewayConfig(
    inference_table_config=AiGatewayInferenceTableConfig(
        enabled=True,
        catalog_name=catalog,
        schema_name=schema,
        table_name_prefix="cc-meta-llama-3-1-8b-instruct_inference"
    )
)

endpoint_config = EndpointCoreConfigInput(
    name=serving_endpoint_name,
    served_entities=[
        ServedEntityInput(
            entity_name=registered_model_name,
            entity_version=latest_version,
            min_provisioned_throughput=0, # The minimum tokens per second that the endpoint can scale down to.
            max_provisioned_throughput=10900,# The maximum tokens per second that the endpoint can scale up to. 
            scale_to_zero_enabled=True
        )
    ]
)

existing_endpoint = next(
    (e for e in w.serving_endpoints.list() if e.name == serving_endpoint_name), None
)

if existing_endpoint is None:
    print(f"Creating the endpoint {serving_endpoint_name}, this will take a few minutes to package and deploy the endpoint...")
    w.serving_endpoints.create_and_wait(name=serving_endpoint_name, config=endpoint_config, ai_gateway=ai_gateway_config)
else:
    print(f"Endpoint {serving_endpoint_name} already exists...")
# Out:
# Endpoint cc-meta-llama-3-1-8b-instruct already exists...

# %%
test_table_name = "hf_pubmed_test"
pred = spark.sql(f"""
        SELECT
            ai_query('{serving_endpoint_name}', concat('{system_prompt}', prompt)) AS prediction,
            response,
            prompt
        FROM {catalog}.{schema}.{test_table_name}
        """)
pred.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prediction</th><th>response</th><th>prompt</th></tr></thead><tbody><tr><td>BACKGROUND</td><td>BACKGROUND</td><td>Many pathogenic processes and diseases are the result of an erroneous activation of the complement cascade and a number of inhibitors of complement have thus been examined for anti-inflammatory actions .</td></tr><tr><td>BACKGROUND</td><td>BACKGROUND</td><td>It was recently demonstrated that supraphysiological concentrations of the endogenous complement inhibitor MAp44 ( also denoted MAP1 ) protect against myocardial reperfusion injury .</td></tr><tr><td>OBJECTIVE</td><td>BACKGROUND</td><td>In the present study , we examined the association between outcome after acute myocardial infarction ( MI ) and the plasma levels of MAp44 and its related proteins MASP-1 and MASP-3 in patients with first-time MI .</td></tr><tr><td>RESULTS</td><td>BACKGROUND</td><td>In addition , we compared plasma levels of MAp44 , MASP-1 , and MASP-3 in MI patients to levels in a healthy control group .</td></tr><tr><td>RESULTS</td><td>METHODS</td><td>A total of 192 MI patients and 140 control persons were included .</td></tr><tr><td>METHODS</td><td>METHODS</td><td>Plasma samples were obtained and analysed with time-resolved immunofluorometric assays determining the plasma levels of MAp44 , MASP-1 , and MASP-3 .</td></tr><tr><td>RESULTS</td><td>METHODS</td><td>The myocardial outcomes ( salvage index and final infarct size ) were measured by gated single-photon emission CT. .</td></tr><tr><td>RESULTS</td><td>RESULTS</td><td>MI patients had 18 % higher plasma levels of MAp44 ( IQR 11-25 % ) as compared to the healthy control group ( p < 0.001 .</td></tr><tr><td>RESULTS</td><td>RESULTS</td><td>However , neither salvage index ( Spearman rho -0.1 , p = 0.28 ) nor final infarct size ( Spearman rho 0.02 , p = 0.83 ) correlated with plasma levels of MAp44 .</td></tr><tr><td>RESULTS</td><td>RESULTS</td><td>Likewise , MASP-1 and MASP-3 were elevated in MI patients ( p = 0.002 and p < 0.001 ) , but the levels were not correlated to outcome .</td></tr></tbody></table></div>

# %%
total_count = pred.count()
correct_predictions = pred.filter(col("prediction") == col("response")).count()
overall_accuracy = correct_predictions / total_count

print(f"Total samples: {total_count}")
print(f"Finetuned Accuracy: {overall_accuracy:.4f}")
# Out:
# Total samples: 29493
# Finetuned Accuracy: 0.6445

# %% [markdown]
# Our baseline accuracy was 63%, and our new accuracy after fine-tuning is 65%. With more tweaking and epochs, we likely could have improved the model performance even more, but let's move on to combining our fine-tuned model with automatic prompt optimization for great performance gains!
